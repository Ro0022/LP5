# %%
from keras.datasets import imdb
from keras import models
from keras import layers
import numpy as np

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)

def vectorize(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))

    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1

    return results

X_train = vectorize(X_train)
X_test = vectorize(X_test)

model = models.Sequential()

model.add(layers.Dense(50, activation='relu', input_shape=(10000,)))
model.add(layers.Dropout(0.3))

model.add(layers.Dense(50, activation='relu'))
model.add(layers.Dropout(0.2))

model.add(layers.Dense(50, activation='relu'))

model.add(layers.Dense(1, activation='sigmoid'))

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=512,
    validation_split=0.2
)

test_loss, test_acc = model.evaluate(X_test, y_test)

print("Accuracy:", test_acc)
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7596 - loss: 0.5064 - val_accuracy: 0.8802 - val_loss: 0.3049
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9057 - loss: 0.2438 - val_accuracy: 0.8918 - val_loss: 0.2683
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9427 - loss: 0.1625 - val_accuracy: 0.8916 - val_loss: 0.2955
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9646 - loss: 0.1073 - val_accuracy: 0.8892 - val_loss: 0.3243
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9780 - loss: 0.0704 - val_accuracy: 0.8838 - val_loss: 0.3944
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9870 - loss: 0.0435 - val_accuracy: 0.8830 - val_loss: 0.4798
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9905 - loss: 0.0300 - val_accuracy: 0.8782 - val_loss: 0.5407
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9929 - loss: 0.0236 - val_accuracy: 0.8802 - val_loss: 0.5841
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9955 - loss: 0.0162 - val_accuracy: 0.8772 - val_loss: 0.6240
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9956 - loss: 0.0150 - val_accuracy: 0.8796 - val_loss: 0.6964
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9948 - loss: 0.0172 - val_accuracy: 0.8770 - val_loss: 0.7096
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9956 - loss: 0.0133 - val_accuracy: 0.8808 - val_loss: 0.6973
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.8796 - val_loss: 0.7880
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9958 - loss: 0.0112 - val_accuracy: 0.8770 - val_loss: 0.7675
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9969 - loss: 0.0098 - val_accuracy: 0.8798 - val_loss: 0.7861
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9977 - loss: 0.0072 - val_accuracy: 0.8786 - val_loss: 0.8342
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9973 - loss: 0.0080 - val_accuracy: 0.8826 - val_loss: 0.7890
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9972 - loss: 0.0081 - val_accuracy: 0.8788 - val_loss: 0.8394
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9969 - loss: 0.0086 - val_accuracy: 0.8822 - val_loss: 0.8446
# Epoch 20/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.8788 - val_loss: 0.8459
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8639 - loss: 0.9076
# Accuracy: 0.8639199733734131
